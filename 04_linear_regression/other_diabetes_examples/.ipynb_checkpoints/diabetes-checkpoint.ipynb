# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %% [markdown]
# EDA:

# %%
diabetes = load_diabetes()
df = pd.DataFrame(data = diabetes.data, columns = diabetes.feature_names)
print("Key of diabetes dataset: \n{}" .format(diabetes.keys()))
print('Shape of the data:\n {}' .format(diabetes['data'].shape))
column_names = df.columns.to_list()
ax = df[column_names].plot(kind='box', title='Visual Inspection', showmeans=True, figsize=(30,20))
print(column_names)
# Out:
# Key of diabetes dataset:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])
# Shape of the data:
#  (442, 10)
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %% [markdown]
# Look for outliers in numerical variables:

# %%
##discovering outliers with IQR-score
outliers_array = []
for name in df.columns:
    Q1 = df[name].quantile(0.05)
    Q3 = df[name].quantile(0.95)
    IQR = Q3 - Q1
    print(f'{name} IQR = {IQR}')
    logical_index_outliers = (df[name] < (Q1 - 1.5 * IQR)) |(df[name] > (Q3 + 1.5 * IQR))
    positives = np.where(logical_index_outliers == True)[0]
    print(f'{name} Outlier indexes: {positives}')
# Out:
# age IQR = 0.1561991533938408
# age Outlier indexes: []
# sex IQR = 0.0953217552468077
# sex Outlier indexes: []
# bmi IQR = 0.151971502417207
# bmi Outlier indexes: []
# bp IQR = 0.15802776484249442
# bp Outlier indexes: []
# s1 IQR = 0.15678982819201864
# s1 Outlier indexes: []
# s2 IQR = 0.15217449500662322
# s2 Outlier indexes: []
# s3 IQR = 0.14339979246919132
# s3 Outlier indexes: []
# s4 IQR = 0.1571618738104968
# s4 Outlier indexes: []
# s5 IQR = 0.15117512138190897
# s5 Outlier indexes: []
# s6 IQR = 0.1574000627637189
# s6 Outlier indexes: []

# %% [markdown]
# Examine the dataset:

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
df.dtypes
# Out:
# age    float64
# sex    float64
# bmi    float64
# bp     float64
# s1     float64
# s2     float64
# s3     float64
# s4     float64
# s5     float64
# s6     float64
# dtype: object

# %%
df.head(5)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %% [markdown]
# Check the distributions of the variables:

# %%
for column in df.columns:
    df.hist(column = column)

# %%
plt.figure(figsize=(10,10))
ax = sns.boxplot(data = df, orient="h", palette = "Set2")

# %% [markdown]
# No transformations are needed, we can proceed with part 2.

# %%
X_train, X_test, y_train, y_test = train_test_split(diabetes['data'],
                                                        diabetes['target'],
                                                        random_state=0)

# %%
# Transform into numpy arrays for easier manipulations:
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_b = np.c_[np.ones((331, 1)), X_train] # add x0 = 1 to each instance, shape 331 x 11
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y_train)  # normal equation

# %%
print(theta_best)
# Out:
# [ 153.06798218  -43.26774487 -208.67053951  593.39797213  302.89814903
#  -560.27689824  261.47657106   -8.83343952  135.93715156  703.22658427
#    28.34844354]

# %%
X_test_b = np.c_[np.ones((111, 1)), X_test]

# %%
y_pred = X_test_b.dot(theta_best)

# %%
# Measure the model:
mse = mean_squared_error(y_test, y_pred)
r = r2_score(y_test, y_pred)

# %%
print(mse)
print(r)
# Out:
# 3180.1988368427333
# 0.35940090989715423

# %%
# compare with sklearn linear regression model:
lin_reg = LinearRegression()
reg = lin_reg.fit(X_train, y_train)
print("Intercept={}, Slope={}".format(lin_reg.intercept_, lin_reg.coef_))
# Out:
# Intercept=153.06798218266258, Slope=[ -43.26774487 -208.67053951  593.39797213  302.89814903 -560.27689824
#   261.47657106   -8.83343952  135.93715156  703.22658427   28.34844354]

# %%
reg.score(X_test, y_test)
# Out:
# 0.35940090989715534

# %%
theta_best_svd, residuals, rank, s = np.linalg.lstsq(X_train, y_train, rcond=1e-6)
theta_best_svd
# Out:
# array([ -14.43873567, -121.16253578,  540.32710319,  225.46947864,
#         -93.16143374, -406.08969482,   26.13059411,  533.16811998,
#         455.9198704 ,   52.79747162])

# %% [markdown]
# Batch Gradient Descent:

# %%
etta = 0.1 # learning rate
n_iterations = 100
m=len(y_train)

theta = np.random.randn(11,1) # random initialization <11x1>

for iteration in range(n_iterations):
    predictions = np.array(X_b.dot(theta))
    difference = np.subtract(predictions, y_train.reshape(-1,1))
    gradients = 2/m * X_b.T.dot(difference)
    theta = theta - etta * gradients
print(theta)
# Out:
# [[152.00254109]
#  [ 13.1614001 ]
#  [  4.07323986]
#  [ 44.77241002]
#  [ 33.21930481]
#  [ 13.59340791]
#  [ 10.76839299]
#  [-28.94522176]
#  [ 30.01178146]
#  [ 42.3937789 ]
#  [ 27.45382257]]

# %% [markdown]
# Comparing batch gradient descent and the previous results:

# %%
y_pred_grad = X_test_b.dot(theta)

# %%
mse = mean_squared_error(y_test, y_pred_grad)
r = r2_score(y_test, y_pred_grad)
print(mse, r)
# Out:
# 4436.588830440124 0.1063216755459313

# %% [markdown]
# It's quite a bit worse. Try to improve with grid search:

# %%
def gradient_descent_prediction(learning_rate: float) -> float:
    etta = learning_rate
    n_iterations = 100
    m=len(y_train)

    theta = np.random.randn(11,1) # random initialization <11x1>
    y_pred = 0

    for iteration in range(n_iterations):
        predictions = np.array(X_b.dot(theta))
        difference = np.subtract(predictions, y_train.reshape(-1,1))
        gradients = 2/m * X_b.T.dot(difference)
        theta = theta - etta * gradients
        y_pred = X_test_b.dot(theta)
    return y_pred

# %%
best_score = 0
best_parameter = 100000
# note the values have been tuned in the list starting from the
# general [0.001, 0.01, 0.1, 1, 10, 100].
for etta in [0.9, 0.92, 0.94, 0.96, 0.98, 1]:
    # for each combination of parameters, evaluate the model
    y_pred = gradient_descent_prediction(etta)
    new_score = r2_score(y_test,y_pred)
    if new_score > best_score:
        best_score = new_score
        best_parameter = etta
print("Best score: {:.7f}".format(best_score))
print("Best parameters: {}".format(best_parameter))
# Out:
# Best score: 0.3575108
# Best parameters: 0.98

# %% [markdown]
# The results are now comparable to the other methods.
# How close can it get with stochastic gradient descent?

# %%
n_epochs = 15000
t0, t1 = 5, 50 # learning schedule hyper-parameters

def learning_schedule(t):  # keeping this since we have not seen others.
  return t0/(t+t1)

theta = np.random.randn(11,1) # random initialization

for epoch in range(n_epochs):
  for i in range(m):
    random_index = np.random.randint(m)
    xi = X_b[random_index:random_index+1]
    yi = y_train[random_index:random_index+1]
    gradients = 2 * xi.T.dot(xi.dot(theta) - yi)
    eta = learning_schedule(epoch * m + i)
    theta = theta - eta * gradients
y_pred_stochastic = X_test_b.dot(theta)
print(r2_score(y_test,y_pred_stochastic))
# Out:
# 0.31165940576044704

# %% [markdown]
# To obtain the same result with this setup we need to crank
# up the epochs by quite a bit, but doing so we can get close.
